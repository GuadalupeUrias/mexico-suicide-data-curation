# %% [markdown]
# # 05 - Documentacion
# Genera docs/data_dictionary.md a partir del dataset consolidado multi-anio
# (data/processed/), usando las descripciones oficiales del diseno de registro
# INEGI (DEFUN_DESCRIPTIONS en src/cleaning_utils.py).
#
# Handoff previo: 04_multi_year_pilot.ipynb
# (data/processed/suicidio_2019_2024_consolidado.csv, 49,918 registros).

# %%
import pandas as pd
import sys
sys.path.append('../src')
from cleaning_utils import generar_data_dictionary

# %% [markdown]
# ## 1. Cargar el dataset consolidado (handoff de 04_multi_year_pilot.ipynb)

# %%
df = pd.read_csv('../data/processed/suicidio_2019_2023_consolidado.csv', encoding='utf-8', low_memory=False, dtype=str)
print(f'Registros cargados: {len(df):,} (esperado: 49,918)')
print(f'Columnas: {df.shape[1]}')
df.head()
# Out:
# Registros cargados: 49,918 (esperado: 49,918)
# Columnas: 77
#   Ent_regis Mun_regis Ent_resid Mun_resid Tloc_resid Loc_resid Ent_ocurr  \
# 0        01       001        01       001         15      0001        01
# 1        01       001        01       001         15      0001        01
# 2        01       001        01       001         15      0001        01
# 3        01       001        01       001         15      0001        01
# 4        01       001        01       001         15      0001        01
#
#   Mun_ocurr Tloc_ocurr Loc_ocurr  ... Nacesp_cve Sem_gest Gramos Cirugia  \
# 0       001         15      0001  ...        NaN      NaN    NaN     NaN
# 1       001         15      0001  ...        NaN      NaN    NaN     NaN
# 2       001         15      0001  ...        NaN      NaN    NaN     NaN
# 3       001         15      0001  ...        NaN      NaN    NaN     NaN
# 4       001         15      0001  ...        NaN      NaN    NaN     NaN
#
#   Natviole Usonecrops Encefalica Donador edad_valor edad_unidad
# 0      NaN        NaN        NaN     NaN         36       anios
# 1      NaN        NaN        NaN     NaN         36       anios
# 2      NaN        NaN        NaN     NaN         43       anios
# 3      NaN        NaN        NaN     NaN         30       anios
# 4      NaN        NaN        NaN     NaN         22       anios
#
# [5 rows x 77 columns]

# %% [markdown]
# ## 2. Generar diccionario de datos
# Usa DEFUN_DESCRIPTIONS (descripciones oficiales INEGI) para documentar cada columna:
# tipo de dato, % de nulos, valores unicos y ejemplo. Incluye 'anio_dataset' y las
# columnas derivadas del piloto multi-anio. Guarda directo en docs/.

# %%
df_dicc = generar_data_dictionary(df, output_path='../docs/data_dictionary.md')
df_dicc
# Out:
# Diccionario guardado en: ../docs/data_dictionary.md
# Variables documentadas: 77 de 77 (completo)
#        variable                                        descripcion tipo_dato  \
# 0     Ent_regis                     Entidad federativa de registro       str
# 1     Mun_regis                              Municipio de registro       str
# 2     Ent_resid  Entidad federativa de residencia habitual del ...       str
# 3     Mun_resid     Municipio de residencia habitual del fallecido       str
# 4    Tloc_resid  Tamano de localidad de residencia habitual (as...       str
# ..          ...                                                ...       ...
# 72   Usonecrops  Los hallazgos de la necropsia se usaron en la ...       str
# 73   Encefalica            Presento muerte encefalica (1=Si, 2=No)       str
# 74      Donador             Fue donador(a) de organos (1=Si, 2=No)       str
# 75   edad_valor  Valor numerico de la edad, ya separado de su u...       str
# 76  edad_unidad  Unidad de la edad: horas/dias/meses/anios/no_e...       str
#
#     pct_nulos  n_unicos ejemplo
# 0        0.00        32      01
# 1        0.00       178     001
# 2        0.00        36      01
# 3        0.00       380     001
# 4        0.00        18      15
# ..        ...       ...     ...
# 72      61.32         2       1
# 73      47.19         4       8
# 74      47.19         4       8
# 75       0.94        93      36
# 76       0.00         2   anios
#
# [77 rows x 6 columns]

# %% [markdown]
# ## 3. Revisar columnas pendientes (TODO)
# Si aparece alguna fila con TODO, es una columna nueva que no esta en
# DEFUN_DESCRIPTIONS todavia (ej. una columna derivada agregada en el piloto
# multi-anio que no existia en el pipeline de un solo anio). Documentarla en
# cleaning_utils.py, no dejarla sin descripcion en el repo final.

# %%
df_dicc[df_dicc['descripcion'].str.startswith('**TODO')]
# Out:
# Empty DataFrame
# Columns: [variable, descripcion, tipo_dato, pct_nulos, n_unicos, ejemplo]
# Index: []

# %% [markdown]
# ## 4. Hallazgos y siguientes pasos
# _Documentar aqui cualquier ajuste hecho al diccionario y trasladar el estado
# final a methodology.md (referencia a la fuente del diseno de registro oficial)._
